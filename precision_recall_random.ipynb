# %%
import learnHeat as lh
from importlib import reload
lh = reload(lh)
import numpy as np
np.set_printoptions(precision=5)
np.set_printoptions(suppress=True)

# %%
X,L,H,tau=lh.create_signal(N=15,M=100,p=0.3,tau_ground=[1,2,3],se=0)

# %%
result = lh.learn_heat(X=X,alpha=0.07,beta=0.03,max_iter=50)
# Out:
# Learning progress:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
precision, recall = lh.heat_scores(result["L"],L,num_trials=20)

# %%
import matplotlib.pyplot as plt
plt.scatter(recall,precision)
plt.title("N=15,M=100,p=0.3,tau_ground=[1,2,3],se=0,alpha=0.07,beta=0.03")
plt.xlabel("Recall")
plt.ylabel("Precision")
# Out:
# Text(0, 0.5, 'Precision')

# %% [markdown]
# Why does this happen? It can happen, false positives go up and then true positives go up.

# %%
precision[5], precision[6], precision[7]
# Out:
# (0.7241379310344828, 0.631578947368421, 0.8333333333333334)
